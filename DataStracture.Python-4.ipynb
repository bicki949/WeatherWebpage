# %% [markdown]
# # DataStracture-Python

# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %%
l=[]

# %%
list
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
type(l)
# Out:
# list

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(10)
l.append(20)
l.append(30)

# %%
l
# Out:
# [10, 10, 20, 30]

# %%
len(l)
# Out:
# 4

# %%
l.append(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 l.append(10,20,30)
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l.copy()
# Out:
# [10, 10, 20, 30]

# %%
l
# Out:
# [10, 10, 20, 30]

# %%
l1=[10,20,30]
l1
# Out:
# [10, 20, 30]

# %%
l1=l1.copy()

# %%
l1
# Out:
# [10, 20, 30]

# %%
print(l)
# Out:
# [10, 10, 20, 30]

# %%
print(l)
print(l1)
# Out:
# [10, 10, 20, 30]
# [10, 20, 30]

# %%
l=l1

# %%
l==l1
# Out:
# True

# %%
l2=[1,2,3,4]

# %%
l2
# Out:
# [1, 2, 3, 4]

# %%
l3=[4,3,2,1]
l3
# Out:
# [4, 3, 2, 1]

# %%
l2==l3
# Out:
# False

# %%
l2.append(20)

# %%
l2
# Out:
# [1, 2, 3, 4, 20]

# %%
print(l2)
# Out:
# [1, 2, 3, 4, 20]

# %%
print(l2)
print(l3)
# Out:
# [1, 2, 3, 4, 20]
# [4, 3, 2, 1]

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
l3=[10,3.2,True,1+2j,'nit']
l3
# Out:
# [10, 3.2, True, (1+2j), 'nit']

# %%
l3.copy()
# Out:
# [10, 3.2, True, (1+2j), 'nit']

# %%
print(l)
print(l1)
print(l2)
print(l3)
# Out:
# [10, 20, 30]
# [10, 20, 30]
# []
# [10, 3.2, True, (1+2j), 'nit']

# %%
l2.append(10)

# %%
l2
# Out:
# [10]

# %%
print(l2)
# Out:
# [10]

# %%
l2[:]
# Out:
# [10]

# %%
l3[::2]
# Out:
# [10, True, 'nit']

# %%
l2.append(20)

# %%
l2
# Out:
# [10, 20]

# %%
l2.append(30)

# %%
l2
# Out:
# [10, 20, 30]

# %%
print(l2)
# Out:
# [10, 20, 30]

# %%
l2[0]=1000

# %%
l2
# Out:
# [1000, 20, 30]

# %%
l
# Out:
# [10, 20, 30]

# %%
l[-1]=100

# %%
l
# Out:
# [10, 20, 100]

# %%
print(l)
print(l1)
print(l2)
print(l3)
# Out:
# [10, 20, 100]
# [10, 20, 100]
# [1000, 20, 30]
# [10, 3.2, True, (1+2j), 'nit']

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
print(l)
print(l1)
print(l2)
print(l3)
# Out:
# []
# []
# [1000, 20, 30]
# [10, 3.2, True, (1+2j), 'nit']

# %%
l3.clear()

# %%
l3
# Out:
# []

# %%
print(l)
print(l1)
print(l2)
print(l3)
# Out:
# []
# []
# [1000, 20, 30]
# []

# %%
del l2

# %%
l5=[20,20,40,50]
l5
# Out:
# [20, 20, 40, 50]

# %%
del l5

# %%
l5.count(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 l5.count(30)
#
# NameError: name 'l5' is not defined

# %%
l5[10,20,30,40,50]
l5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 l5[10,20,30,40,50]
#       2 l5
#
# NameError: name 'l5' is not defined

# %%
l6=[1000,"True",2.3,1+3J,'abhi']

# %%
l6
# Out:
# [1000, 'True', 2.3, (1+3j), 'abhi']

# %%
l6.copy()
# Out:
# [1000, 'True', 2.3, (1+3j), 'abhi']

# %%
l6.append(2e3)

# %%
l6
# Out:
# [1000, 'True', 2.3, (1+3j), 'abhi', 2000.0]

# %%
l6.count(30)
# Out:
# 0

# %%
l6
# Out:
# [1000, 'True', 2.3, (1+3j), 'abhi', 2000.0]

# %%
l6.count('True')
# Out:
# 1

# %%
l6
# Out:
# [1000, 'True', 2.3, (1+3j), 'abhi', 2000.0]

# %%
l6[::-1]
# Out:
# [2000.0, 'abhi', (1+3j), 2.3, 'True', 1000]

# %%
l6[::2]
# Out:
# [1000, 2.3, 'abhi']

# %%
print(l6)
# Out:
# [1000, 'True', 2.3, (1+3j), 'abhi', 2000.0]

# %%
l6[::-2]
# Out:
# [2000.0, (1+3j), 'True']
